# %%
print("Hello, world!")
print("Samhitha is awesome, she is the best")
print("Nanna is a very good teacher!")
# Out:
# Hello, world!
# Samhitha is awesome, she is the best
# Nanna is a very good teacher!

# %%
name = "Satya"
age = 19
height = 5.1
is_student = True

print(name, "is a", age, "year old.")
print("Is student:", is_student)
# Out:
# Satya is a 19 year old.
# Is student: True

# %%
print(42)
print(3.14)
# Out:
# 42
# 3.14
